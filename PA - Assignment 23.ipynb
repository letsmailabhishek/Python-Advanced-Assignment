# %% [markdown]
# Q1. If you have any, what are your choices for increasing the comparison between different figures on
# the same graph?

# %% [markdown]
# - For comparing the different figures on the same graph we can line plot,bar plot,histogram with the help of seaborn or matplotlib libraries.

# %% [markdown]
# Q2. Can you explain the benefit of compound interest over a higher rate of interest that does not
# compound after reading this chapter?

# %% [markdown]
# - Interest is the cost of borrowing money, where the borrower pays a fee to the lender for the loan. The interest, typically expressed as a percentage, can be either simple or compounded. Simple interest is based on the principal amount of a loan or deposit. In contrast, compound interest is based on the principal amount and the interest that accumulates on it in every period. Simple interest is calculated only on the principal amount of a loan or deposit, so it is easier to determine than compound interest.

# %% [markdown]
# ![image.png](attachment:d6891425-282d-454f-a888-01eca7d6ebbf.png)

# %% [markdown]
# ![image.png](attachment:bfe4703f-ac80-46c7-8ffd-a73fc0a327c1.png)

# %% [markdown]
# Q3. What is a histogram, exactly? Name a numpy method for creating such a graph.

# %% [markdown]
# - Histogram :- Histogram always help to know how the descrete quantities are distributed.
# - Like age 1-10 having the value is equal to 200 means the people who have age between 1-10 along with their count 200.This how it tooks bins and based on the count of that range or bin it creates the distribution and that distribution called as histogram.
# - It is the frequency distribution of the set of the class.

# %%
import numpy as np
arr = np.array([12,12,34,22,45,22,67,34,32,32,32,10,10,10])
hist,bins=np.histogram(arr)
print(hist)
print(bins)

# %% [markdown]
# Q4. If necessary, how do you change the aspect ratios between the X and Y axes?

# %%
import matplotlib.pyplot as plt

ax = fig.add_subplot(111,aspect='equal')
ax = fig.add_subplot(111,aspect=1.0)
ax.set_aspect('equal')
plt.axes().set_aspect('equal')

# %% [markdown]
# Q5. Compare and contrast the three types of array multiplication between two numpy arrays: dot
# product, outer product, and regular multiplication of two numpy arrays.

# %% [markdown]
# - Dot Product
#  - This function returns the dot product of two arrays. For 2-D vectors, it is the equivalent to matrix multiplication. For 1-D arrays, it is the inner product of the vectors. For N-dimensional arrays, it is a sum product over the last axis of a and the second-last axis of b.

# %%
import numpy.matlib 
import numpy as np 

a = np.array([[1,2],[3,4]]) 
b = np.array([[11,12],[13,14]]) 
np.dot(a,b)

# %%
[[1*11+2*13, 1*12+2*14],[3*11+4*13, 3*12+4*14]]

# %% [markdown]
# - Outer Product
#  - In Python, we can use the outer() function of the NumPy package to find the outer product of two matrices.

# %%
import numpy as np
  

array1 = np.array([6,2])
array2 = np.array([2,5])
print("Original 1-D arrays:")
print(array1)
print(array2)
  
# Output
print("Outer Product of the two array is:")
result = np.outer(array1, array2)
print(result)

# %%
import numpy as np
p = np.array([3, 6, 8], float)
q = np.array([4, 7, 13], float)
print("The Calculation of Matrixes and vectors are.")
print("p:")
print(p)
print("q:")
print(q)
print("The Outer function used in the p and q are:")
print(np.outer(p, q))

# %% [markdown]
# Q6. Before you buy a home, which numpy function will you use to measure your monthly mortgage
# payment?

# %%
import numpy as np
np.pmt(0.085/12, 12*12, 100000)

# %% [markdown]
# Q7. Can string data be stored in numpy arrays? If so, list at least one restriction that applies to this
# data.

# %%
import numpy as np
arr = np.array(['ste','sgh','ssshg','shs'])
arr[1]='nsssss'
print(arr)  #when I want to change the element at the 1st place that time it is taking max length of element
